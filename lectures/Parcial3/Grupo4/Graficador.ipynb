# %%
# Libraries #
import numpy as np
import matplotlib.pyplot as plt

# %%
font = {'family' : 'Arial',
        'weight' : 'bold',
        'size'   : 10}
f = plt.figure(figsize=(3, 3),dpi=200)

arch=np.loadtxt('filename.txt')
x=arch[:,0]
y=arch[:,1]
plt.plot(x, y,'k',label="Solución númerica")
plt.xlabel("$t$")
plt.ylabel("$y$")
plt.legend()

# %%
y
# Out:
# array([ 0.00000e+00, -9.52761e+03,  1.82406e+03,  7.86122e+03,
#        -3.07691e+03, -6.18534e+03,  3.83571e+03,  4.59588e+03,
#        -4.18531e+03, -3.15923e+03,  4.21153e+03,  1.91617e+03,
#        -3.99614e+03, -8.86206e+02,  3.61334e+03,  7.19165e+01,
#        -3.12757e+03,  5.36797e+02,  2.59242e+03, -9.58903e+02,
#        -2.05044e+03,  1.21889e+03,  1.53361e+03, -1.34399e+03,
#        -1.06428e+03,  1.36194e+03,  6.56405e+02, -1.29932e+03,
#        -3.16903e+02,  1.18036e+03,  4.71112e+01, -1.02620e+03,
#         1.55867e+02,  8.54488e+02, -2.97910e+02, -6.79321e+02,
#         3.86780e+02,  5.11357e+02, -4.31207e+02, -3.58108e+02,
#         4.40153e+02,  2.24333e+02, -4.22251e+02, -1.12479e+02,
#         3.85409e+02,  2.31428e+01, -3.36557e+02,  4.44904e+01,
#         2.81511e+02, -9.22348e+01, -2.24934e+02,  1.22547e+02,
#         1.70376e+02, -1.38223e+02, -1.20359e+02,  1.42157e+02,
#         7.65033e+01, -1.37150e+02, -3.96695e+01,  1.25784e+02,
# ...
